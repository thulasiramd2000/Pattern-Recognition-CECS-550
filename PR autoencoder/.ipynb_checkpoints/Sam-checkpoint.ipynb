# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from  torchvision.datasets import ImageFolder
from torch.autograd import Variable
import cv2
import numpy as np
import os, random,sys

# %% [markdown]
# # Build an Autoencoder for a human face dataset
#
# We will use a dataset containig images of people and train an autoencoder on it.
#
# ## Step 1
#
# Download and unzip the ``lfw.zip`` file . Adjust the ``path`` variable so that it contains the address of the unzipped folder. We will create a dataloader from this folder.

# %%
path = 'C:/Users/thula/PR autoencoder/lfw'

# %%
transform    = transforms.Compose([transforms.ToTensor()]) 
dataloader = DataLoader(ImageFolder(path, transform,),batch_size=32, shuffle=True)

# %% [markdown]
# This project is compute intensive. If you have a cuda or mps device on your laptop make sure you use that in the training.

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    print ("MPS device not found.")
# Out:
# MPS device not found.

# %%
for x,y in dataloader:
    x = x[0].permute(1, 2, 0)
    print(x.shape)
    plt.imshow(x)
    break
# Out:
# torch.Size([250, 250, 3])

# %% [markdown]
# ## Step 2
# Each datapoint is an image. Get a sample of the data and print its dimensions and explain what each dimension means.

# %%
for x, y in dataloader:
    sample_image = x[0].permute(1, 2, 0)
    print("Sample image dimensions:", sample_image.shape)    
    plt.imshow(sample_image)
    plt.show()
    break
# Out:
# Sample image dimensions: torch.Size([250, 250, 3])

# %%
'''Explanation of Dimensions:

Number of Channels (C): This dimension represents the color channels in the image. For a color image,
C is usually 3 (Red, Green, Blue).

Image Height (H): It represents the number of pixels in the vertical direction of the image.

Image Width (W): It represents the number of pixels in the horizontal direction of the image.

So, for a color image, each datapoint has a shape of (3, H, W), where 3 is the number of color channels  (RGB),
H is the height of the image, and W is the width of the image. 

The values within these dimensions encode the pixel intensities of the image.'''
# Out:
# 'Explanation of Dimensions:\n\nNumber of Channels (C): This dimension represents the color channels in the image. For a color image,\nC is usually 3 (Red, Green, Blue).\n\nImage Height (H): It represents the number of pixels in the vertical direction of the image.\n\nImage Width (W): It represents the number of pixels in the horizontal direction of the image.\n\nSo, for a color image, each datapoint has a shape of (3, H, W), where 3 is the number of color channels  (RGB),\nH is the height of the image, and W is the width of the image. \n\nThe values within these dimensions encode the pixel intensities of the image.'

# %% [markdown]
# # Step 3
#
# Create a new pytorch model calss for your autoencoder. You can use Conv2d, MaxPool2d, BatchNorm2d, ConvTranspose2d and Linear Layers as as well as activation functions. Optionally, you can use UpSample, AveragePool2d and Interpolate2d as well.
#
# **Create seperate functions for the encoder and decoder.**

# %%
class AE(nn.Module):
    
    def __init__(self):
        super(AE,self).__init__()
        self.encoder_layers = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=1, stride=1, padding=0),  
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.MaxPool2d(1, stride=1),
        )
        self.decoder_layers = nn.Sequential(
            nn.ConvTranspose2d(16, 3, kernel_size=1, stride=1, padding=0, output_padding=0),  
            nn.BatchNorm2d(3),
            nn.ReLU(True),
            nn.Tanh() 
        )

    def encoder(self, x):
        x_encoded = self.encoder_layers(x)
        return x_encoded

    def decoder(self, x):
        x_decoded = self.decoder_layers(x)
        return x_decoded
    
    def forward(self, x):
        x_encoded = self.encoder(x)

        x_decoded = self.decoder(x_encoded)

        return x_decoded, x_encoded
    
    
autoencoder_model = AE()
    
print(autoencoder_model)
# Out:
# AE(
#   (encoder_layers): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder_layers): Sequential(
#     (0): ConvTranspose2d(16, 3, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Tanh()
#   )
# )

# %% [markdown]
# ## Step 4
# Create an instance of the class, pass an image to the model, print the shape of the output of the **encoder** and the **decoder**. Check the dimensions and make sure your forward path is working properly.

# %%
model = AE()

# %%
for x, y in dataloader:
    output_decoded, output_encoded = model(x)
    
    print("Encoder output shape:", output_encoded.shape)
    print("Decoder output shape:", output_decoded.shape)
    
    original_image = x[0].permute(1, 2, 0).numpy()
    reconstructed_image = output_decoded[0].detach().permute(1, 2, 0).numpy()

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.title("Original Image")
    plt.imshow(original_image)


    plt.subplot(1, 2, 2)
    plt.title("Reconstructed Image")
    plt.imshow(reconstructed_image)
    plt.show()
    break
# Out:
# Encoder output shape: torch.Size([32, 16, 250, 250])
# Decoder output shape: torch.Size([32, 3, 250, 250])

# %%
'''After checking the dimensions we can clearly see that the forward path is working properly.'''
# Out:
# 'After checking the dimensions we can clearly see that the forward path is working properly.'

# %% [markdown]
# ##  Step 5
# Print total number of parameters in the model, explain what loss function you should use, create an optimizer for training

# %%
from torchsummary import summary
summary(model, (3, 64, 64))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10664\542687211.py in <module>
# ----> 1 from torchsummary import summary
#       2 summary(model, (3, 64, 64))
#
# ModuleNotFoundError: No module named 'torchsummary'

# %%
optim = torch.optim.Adam(model.parameters(), lr=0.1)

# %%
loss_function =nn.MSELoss()

'''I have used the Mean Squared Error (MSE) loss function in autoencoders for the following reasons:

Reconstruction Objective: Autoencoders aim to minimize the difference between input and reconstructed data, 
and MSE quantifies this difference effectively.

Sensitivity to Deviations: Squaring differences in MSE amplifies larger errors, making the model more sensitive 
to significant deviations in reconstruction.

Mathematical Simplicity: MSE is mathematically straightforward, easy to compute, and suitable for data that 
follows a Gaussian distribution.

Derivatives for Optimization: MSE has well-defined gradients, facilitating efficient optimization using 
gradient-based algorithms.
The optimizer, in this case, is Adam with a learning rate of 0.1. '''
# Out:
# 'I have used the Mean Squared Error (MSE) loss function in autoencoders for the following reasons:\n\nReconstruction Objective: Autoencoders aim to minimize the difference between input and reconstructed data, \nand MSE quantifies this difference effectively.\n\nSensitivity to Deviations: Squaring differences in MSE amplifies larger errors, making the model more sensitive \nto significant deviations in reconstruction.\n\nMathematical Simplicity: MSE is mathematically straightforward, easy to compute, and suitable for data that \nfollows a Gaussian distribution.\n\nDerivatives for Optimization: MSE has well-defined gradients, facilitating efficient optimization using \ngradient-based algorithms.\nThe optimizer, in this case, is Adam with a learning rate of 0.1. '

# %% [markdown]
# ##  Step 6
# Write a training loop and start trainng the model for several epochs. Report the loss value at the end of each epoch and monitor it. If your loss is not decreasing what do you have to do to troubleshoot it ?

# %%
num_epochs = 10

# %%
for epoch in range(num_epochs):
    total_loss = 0.0

    model.train()

    for x, _ in dataloader:
        output_decoded, _ = model(x)
        loss = loss_function(output_decoded, x)
        optim.zero_grad()
        loss.backward()
        optim.step()
        total_loss += loss.item()

    average_loss = total_loss / len(dataloader)


    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {average_loss:.4f}')
# Out:
# Epoch [1/10], Loss: 0.0026
# Epoch [2/10], Loss: 0.0010
# Epoch [3/10], Loss: 0.0009
# Epoch [4/10], Loss: 0.0008
# Epoch [5/10], Loss: 0.0008
# Epoch [6/10], Loss: 0.0007
# Epoch [7/10], Loss: 0.0007
# Epoch [8/10], Loss: 0.0007
# Epoch [9/10], Loss: 0.0006
# Epoch [10/10], Loss: 0.0006

# %%
'''If the loss stagnates during training, troubleshooting involves a systematic approach.
Begin by reviewing data preprocessing for consistency and proper normalization. Adjust the learning rate and 
experiment with different optimizers. Check the model's complexity and architecture, considering additions if 
necessary. Monitor loss curves for signs of overfitting. Employ techniques like data augmentation, label 
verification, and adjustments to batch sizes and activation functions. Implement regularization methods and 
evaluate the suitability of the chosen loss function. Systematically address these factors to diagnose and 
resolve the issue of a stagnant or increasing loss during training.'''
# Out:
# "If the loss stagnates during training, troubleshooting involves a systematic approach.\nBegin by reviewing data preprocessing for consistency and proper normalization. Adjust the learning rate and \nexperiment with different optimizers. Check the model's complexity and architecture, considering additions if \nnecessary. Monitor loss curves for signs of overfitting. Employ techniques like data augmentation, label \nverification, and adjustments to batch sizes and activation functions. Implement regularization methods and \nevaluate the suitability of the chosen loss function. Systematically address these factors to diagnose and \nresolve the issue of a stagnant or increasing loss during training."

# %% [markdown]
# ##  Step 7
#
# Take a random image from the dataset and plot it against the reconstructed (encoded + decoded) image.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
model.eval()

random_index = np.random.randint(len(dataloader.dataset))
sample_image, _ = dataloader.dataset[random_index]

sample_image = sample_image.unsqueeze(0)

with torch.no_grad():
    reconstructed_image, _ = model(sample_image)

original_image_np = sample_image.squeeze().permute(1, 2, 0).numpy()
reconstructed_image_np = reconstructed_image.squeeze(-4).permute(1, 2, 0).numpy()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(original_image_np)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Reconstructed Image')
plt.imshow(reconstructed_image_np)
plt.axis('off')

plt.show()

# %% [markdown]
# ##  Step 8
#
# In step 7, add a small normaly distrubuted noise to the latent (hidden) representation of the input image and then decode it again. How is adding noise affecting the decoded image ?

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

model.eval()

for x, y in dataloader:
    _, latent_representation = model(x)

    noise = torch.randn_like(latent_representation) * 0.6
    noisy_latent_representation = latent_representation + noise

    decoded_output = model.decoder(latent_representation)
    noisy_decoded_output = model.decoder(noisy_latent_representation)

    original_image = x[0].permute(1, 2, 0).numpy()
    reconstructed_image = decoded_output[0].detach().permute(1, 2, 0).numpy()
    noisy_reconstructed_image = noisy_decoded_output[0].detach().permute(1, 2, 0).numpy()

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.title("Original Image")
    plt.imshow(original_image)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title("Reconstructed Image")
    plt.imshow(reconstructed_image)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title("Noisy Reconstructed Image")
    plt.imshow(noisy_reconstructed_image)
    plt.axis('off')

    plt.show()
    break

# %%
p'''Adding noise to the latent representation and subsequently decoding it introduces a regularization effect on 
the autoencoder, influencing the decoded image in several ways. This regularization promotes robustness by 
encouraging the model to learn more meaningful features and preventing overreliance on specific patterns. 
The decoded image often exhibits a smoothing effect, resulting in cleaner and more generalized representations. 
The regularization also enhances the model's denoising capability, making it adept at handling inherent noise or 
variations in the input data. Moreover, the noise injection encourages the development of a continuous and 
structured latent space, fostering better interpolation between different data points.
Overall, this technique contributes to a more resilient, generalizable, and denoised autoencoder.'''
# Out:
# "Adding noise to the latent representation and subsequently decoding it introduces a regularization effect on \nthe autoencoder, influencing the decoded image in several ways. This regularization promotes robustness by \nencouraging the model to learn more meaningful features and preventing overreliance on specific patterns. \nThe decoded image often exhibits a smoothing effect, resulting in cleaner and more generalized representations. \nThe regularization also enhances the model's denoising capability, making it adept at handling inherent noise or \nvariations in the input data. Moreover, the noise injection encourages the development of a continuous and \nstructured latent space, fostering better interpolation between different data points.\nOverall, this technique contributes to a more resilient, generalizable, and denoised autoencoder."

# %%
'''Citations
1. Autoencoders for Image Reconstruction in Python and Keras - 
https://stackabuse.com/autoencoders-for-image-reconstruction-in-python-and-keras/
2. The Magic of Autoencoders-https://medium.com/mlearning-ai/the-magic-of-autoencoders-73162e9bd43f '''
